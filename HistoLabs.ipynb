# %% [markdown]
# <a href="https://colab.research.google.com/github/nicjmill/masters_data/blob/main/HistoLabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
#Connecting
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
os.chdir("/content/gdrive/My Drive/mastersdata")

# %%
path_FG = '/content/gdrive/My Drive/mastersdata/FlurogoldResults1.csv'
h_FG = pd.read_csv(path_FG)

# %%
data_FG = h_FG.iloc[9:,1:]
data_TFG = h_FG.iloc[:8,1:]
print(h_FG)
print(data_TFG.iloc)
ages = [ 'P9', 'P12', 'P15', 'P18', 'P21']

X = np.arange(5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ages, data_FG.iloc[0], color = 'b', width = 0.25)
ax.errorbar(ages, data_FG.iloc[0],yerr = data_FG.iloc[1], fmt = 'o', color = 'k')
test= 0
for i in range(len(ages)):
  for j in range(len(data_TFG.iloc[:8,1])):
    # distribute scatter randomly across whole width of bar
    test = test +1
    ax.scatter(ages, data_TFG.iloc[i,:8], color= 'k')
print(test)
plt.xlabel('Pup Ages')
plt.ylabel('Neuron Count')
#plt.title('FG Counts')

plt.show()
# Out:
#    Unnamed: 0  P9       P12       P15        P18        P21
# 0    Mouse1.1   0  0.000000  2.000000   7.000000  11.000000
# 1    Mouse1.2   0  0.000000  3.000000  10.000000   8.000000
# 2    Mouse1.3   0  0.000000  2.000000   8.000000  14.000000
# 3    Mouse2.1   0  2.000000  4.000000  16.000000  13.000000
# 4    Mouse2.2   0  0.000000  2.000000  12.000000  14.000000
# 5    Mouse2.3   0  1.000000  1.000000   8.000000  10.000000
# 6    Mouse3.1   0  0.000000  0.000000   6.000000   8.000000
# 7    Mouse3.2   0  0.000000  3.000000  12.000000   6.000000
# 8    Mouse3.3   0  0.000000  2.000000   4.000000  15.000000
# 9     Average   0  0.333333  2.111111   9.222222  11.000000
# 10         SD   0  0.707107  1.166667   3.666667   3.201562
# ...
# 40
